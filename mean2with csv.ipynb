# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r"C:\Users\Paras\OneDrive\Desktop\my sql query\book 1\Book1.csv"
dataset = pd.read_csv(file_path)


print(dataset.head())
# Out:
#    tv  radi0  newspaper        name  age
# 0   1     89         52         don   25
# 1  25     56        366       rohan   36
# 2  28     85         24      dalall   45
# 3  47     65         32  kalmilenge   12

# %%
sns.histplot(x="age",data=dataset)
plt.show()

# %%
sns.histplot(x="age",data=dataset)
plt.plot([mn for i in range(0,100)],[i for i in range (0,100)],c="red")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sns.histplot(x="age",data=dataset)
#       2 plt.plot([mn for i in range(0,100)],[i for i in range (0,100)],c="red")
#       3 plt.show()
#
# NameError: name 'sns' is not defined
