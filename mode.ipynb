# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r"C:\Users\Paras\OneDrive\Desktop\my sql query\book 1\Book1.csv"
dataset = pd.read_csv(file_path)


print(dataset.head())
# Out:
#    tv  radi0  newspaper        name  age
# 0   1     89         52         don   25
# 1  25     56        366       rohan   36
# 2  28     85         24      dalall   45
# 3  47     65         32  kalmilenge   12

# %%
 mod = dataset["age"].mode()[0]

# %%
dataset["age"].value_counts()
# Out:
# age
# 25    1
# 36    1
# 45    1
# 12    1
# Name: count, dtype: int64

# %%
sns.histplot(x="age",data=dataset)
plt.show()

# %%
sns.histplot(x="age",data=dataset)
plt.plot([mod for i in range(0,100)],[i for i in range (0,100)],c="yellow",label="mode")
plt.show()
