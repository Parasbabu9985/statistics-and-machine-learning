# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sec_a=np.array([75,65,73,68,72,67])
sec_b=np.array([90,47,43,96,93,51])
no=np.array([1,2,3,4,5,6])

# %%
mean = np.mean(sec_b)
mean
# Out:
# np.float64(70.0)

# %%
plt .figure(figsize=(10,3))
plt.scatter(sec_a,no,label="sec_a")
plt.scatter(sec_b,no,label="sec_b")
plt.plot([70,70,70,70,70,70],no,color="blue",label="mean")
plt.legend()
plt.show()

# %%
BRO I have mostly done DS++ but now I am doing it in data science so with python so the DSA which is left now should I continue with DS++ or with python
